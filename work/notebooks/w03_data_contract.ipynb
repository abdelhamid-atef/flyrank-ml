# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# One row represents one content page measured for one monthly observation.
#
# Time window: I will use March 2026 as the analysis month. This month is used to explore the data and create features without using the final month as the target window.

# %%
from datasets import load_dataset
import pandas as pd

# Load the main table
ds = load_dataset("FlyRank/internship-warehouse", "fact_content_daily_performance")

# Convert to DataFrame
df = ds["train"].to_pandas()

# Show basic information
print("Number of rows:", len(df))
print("\nColumns:")
print(df.columns.tolist())

print("\nFirst 5 rows:")
display(df.head())

# Check date range if a date column exists
for col in ["date", "day", "snapshot_date"]:
    if col in df.columns:
        print(f"\nDate range ({col}):")
        print(df[col].min(), "->", df[col].max())
# Out:
# Resolving data files:   0%|          | 0/18 [00:00<?, ?it/s]
# ...
# fact_content_daily_performance/month=202(…): reconstructing file:   0%|          |  0.00B / 19.6kB
# fact_content_daily_performance/month=202(…): reconstructing file:   0%|          |  0.00B / 3.29MB
# fact_content_daily_performance/month=202(…): reconstructing file:   0%|          |  0.00B / 8.93MB
# fact_content_daily_performance/month=202(…): reconstructing file:   0%|          |  0.00B / 3.22MB
# fact_content_daily_performance/month=202(…): reconstructing file:   0%|          |  0.00B / 21.6MB
# fact_content_daily_performance/month=202(…): reconstructing file:   0%|          |  0.00B / 89.0MB
# fact_content_daily_performance/month=202(…): reconstructing file:   0%|          |  0.00B / 86.2MB
# fact_content_daily_performance/month=202(…): reconstructing file:   0%|          |  0.00B /  134MB
# fact_content_daily_performance/month=202(…): reconstructing file:   0%|          |  0.00B / 90.3MB
# ...

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# ## 2. Fields
#
# ### Features
# - ctr
# - impressions
# - clicks
# - word_count
# - content_age_days
#
# ### Label / Target
# - trend_direction
#
# ### Context
# - month
# - page_id
#
# ### Excluded
# - URL or client identifiers (excluded to protect privacy and because they are not useful for prediction).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# ## 3. Verify it with queries
#
# The following queries verify:
#
# - Number of rows
# - Number of missing values
# - Monthly distribution

# %%
print("Total rows:", len(df))

print("\nMissing values:")
print(df.isnull().sum())

print("\nRows per month:")
print(df["month"].value_counts().sort_index())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8858/2660600355.py in <cell line: 0>()
# ----> 1 print("Total rows:", len(df))
#       2
#       3 print("\nMissing values:")
#       4 print(df.isnull().sum())
#       5
#
# NameError: name 'df' is not defined

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# ## 4. Data limits
#
# This dataset cannot explain why traffic changes happened. It only contains observed search metrics.
#
# The results provide decision support but do not prove causation.
#
# Some factors such as algorithm updates, competitor actions, or external events are not included.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
